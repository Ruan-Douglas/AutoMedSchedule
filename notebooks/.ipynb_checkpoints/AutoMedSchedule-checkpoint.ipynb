# %%
import pandas as pd
import numpy as np

df = pd.read_excel('../data/Modelo_escala.ods', engine = 'odf', skiprows = 3, header = [0, 1])

df = df.drop(columns=['ITEM', 'CRM/BA', 'NOME COMPLETO DA EMPRESA', 'CNPJ'], level = 0)

df
# Out:
#                                                MÉDICO    1    2    3    4  \
#                                    Unnamed: 1_level_1    S    S    D    S
# 0                                            MÉDICO 1   SN   SN  NaN  NaN
# 1                                            MÉDICO 2  NaN  NaN   SD  NaN
# 2                                            MÉDICO 3  NaN  NaN   SN  NaN
# 3                                            MÉDICO 4  NaN  NaN  NaN  NaN
# 4                                            MÉDICO 5  NaN   SD  NaN  NaN
# 5                                            MÉDICO 6  NaN  NaN  NaN  NaN
# 6                                            MÉDICO 7  NaN  NaN  NaN  NaN
# 7                                            MÉDICO 8  NaN  NaN    P    M
# 8                                            MÉDICO 9  NaN  NaN  NaN  NaN
# 9                                           MÉDICO 10    T  NaN  NaN  NaN
# 10                                          MÉDICO 11  NaN  NaN  NaN  NaN
# ...

# %%
df = df.dropna(how = 'all')
df
# Out:
#                                                MÉDICO    1    2    3    4  \
#                                    Unnamed: 1_level_1    S    S    D    S
# 0                                            MÉDICO 1   SN   SN  NaN  NaN
# 1                                            MÉDICO 2  NaN  NaN   SD  NaN
# 2                                            MÉDICO 3  NaN  NaN   SN  NaN
# 3                                            MÉDICO 4  NaN  NaN  NaN  NaN
# 4                                            MÉDICO 5  NaN   SD  NaN  NaN
# 5                                            MÉDICO 6  NaN  NaN  NaN  NaN
# 6                                            MÉDICO 7  NaN  NaN  NaN  NaN
# 7                                            MÉDICO 8  NaN  NaN    P    M
# 8                                            MÉDICO 9  NaN  NaN  NaN  NaN
# 9                                           MÉDICO 10    T  NaN  NaN  NaN
# 10                                          MÉDICO 11  NaN  NaN  NaN  NaN
# ...
